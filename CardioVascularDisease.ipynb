# %% [markdown]
# # **Cardio Vascular Diseases**

# %% [markdown]
# # **Importing all Required Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-bc5a12a5-b987-4d24-b865-5c42187a8fa6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc5a12a5-b987-4d24-b865-5c42187a8fa6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Cardiovascular_Disease_Dataset.csv')

# %% [markdown]
# # **Data exploration and Cleaning**

# %%
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
df.describe()
# Out:
#           patientid         age       gender    chestpain    restingBP  \
# count  1.000000e+03  1000.00000  1000.000000  1000.000000  1000.000000
# mean   5.048704e+06    49.24200     0.765000     0.980000   151.747000
# std    2.895905e+06    17.86473     0.424211     0.953157    29.965228
# min    1.033680e+05    20.00000     0.000000     0.000000    94.000000
# 25%    2.536440e+06    34.00000     1.000000     0.000000   129.000000
# 50%    4.952508e+06    49.00000     1.000000     1.000000   147.000000
# 75%    7.681877e+06    64.25000     1.000000     2.000000   181.000000
# max    9.990855e+06    80.00000     1.000000     3.000000   200.000000
#
#        serumcholestrol  fastingbloodsugar  restingrelectro  maxheartrate  \
# count      1000.000000        1000.000000      1000.000000   1000.000000
# mean        311.447000           0.296000         0.748000    145.477000
# std         132.443801           0.456719         0.770123     34.190268
# ...

# %%
df.isnull().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 14)

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
sns.histplot(df['age'])
plt.show()

sns.boxplot(df['age'])
plt.show()

# %%
sns.boxplot(x='target', y='age', data=df)
plt.show()

sns.scatterplot(x='target' , y='serumcholestrol', data =df)
plt.show()

# %%
sns.scatterplot(x='age', y= 'maxheartrate', data=df)
plt.show()

barplot_df = df.groupby('gender')['target'].mean().reset_index()
sns.barplot(x='gender', y='target', data=barplot_df)
plt.xlabel('Gender (0 = Female, 1 = Male)')
plt.ylabel('Mean Presence of Heart Disease')
plt.title('Mean Heart Disease Presence by Gender')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

df.corr()
# Out:
#                    patientid       age    gender  chestpain  restingBP  \
# patientid           1.000000  0.004978 -0.031263  -0.009679  -0.020926
# age                 0.004978  1.000000 -0.024717   0.037731  -0.016126
# gender             -0.031263 -0.024717  1.000000   0.035402  -0.069727
# chestpain          -0.009679  0.037731  0.035402   1.000000   0.222267
# restingBP          -0.020926 -0.016126 -0.069727   0.222267   1.000000
# serumcholestrol     0.053464  0.035439 -0.120759   0.174731   0.126523
# fastingbloodsugar   0.022331  0.049732  0.023560   0.232059   0.192063
# restingrelectro    -0.003667  0.067736 -0.046634   0.256316   0.219887
# maxheartrate       -0.036486 -0.040092  0.064606   0.114496   0.095569
# exerciseangia       0.014338 -0.037581 -0.051746  -0.027376  -0.046545
# oldpeak            -0.013825 -0.026020  0.331457   0.101345  -0.004225
# slope              -0.010128 -0.015334 -0.051957   0.472731   0.376711
# ...

# %% [markdown]
# # **Data Modeling**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
factors = df[['chestpain', 'restingBP', 'fastingbloodsugar', 'restingrelectro', 'slope', 'noofmajorvessels']]
target = df['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(factors, target, test_size=0.3, random_state=42)

# %%
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_model_predictions = lr_model.predict(X_test)

# %%
print("Accuracy = ",accuracy_score(y_test, lr_model_predictions))
print("Classification Report= ",classification_report(y_test, lr_model_predictions))
print("Confusion Matrix= ",confusion_matrix(y_test, lr_model_predictions))
# Out:
# Accuracy =  0.9666666666666667
# Classification Report=                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       138
#            1       0.97      0.96      0.97       162
#
#     accuracy                           0.97       300
#    macro avg       0.97      0.97      0.97       300
# weighted avg       0.97      0.97      0.97       300
#
# Confusion Matrix=  [[134   4]
#  [  6 156]]

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(n_estimator=100, learning_rate=0.1, random_state=42)
xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)

print("XGBoost Accuracy:", accuracy_score(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
# Out:
# XGBoost Accuracy: 0.9633333333333334
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       138
#            1       0.96      0.98      0.97       162
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.96      0.96       300
# weighted avg       0.96      0.96      0.96       300
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [14:35:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimator" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.9666666666666667
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       138
#            1       0.97      0.97      0.97       162
#
#     accuracy                           0.97       300
#    macro avg       0.97      0.97      0.97       300
# weighted avg       0.97      0.97      0.97       300

# %% [markdown]
# # **Model Tunning**

# %%
param_grid = {
    'C': [0.001, 00.1, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear']
}

# %%
grid_search = GridSearchCV(estimator=lr_model, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.1, 0.1, 1, 10, 100],
#                          'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              scoring='accuracy')

# %%
print("Best Parameters: ", grid_search.best_params_)
print("best Score: ", grid_search.best_score_)
# Out:
# Best Parameters:  {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
# best Score:  0.9385714285714286

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("Classification Report: \n", classification_report(y_test, y_pred))
# Out:
# Accuracy:  0.9633333333333334
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       138
#            1       0.97      0.96      0.97       162
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.96      0.96       300
# weighted avg       0.96      0.96      0.96       300
